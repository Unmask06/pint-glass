# %%
import pint

# %%
ureg = pint.UnitRegistry()

# %%
[d for d in ureg._dimensions]
# Out:
# ['[length]',
#  '[time]',
#  '[current]',
#  '[luminosity]',
#  '[mass]',
#  '[substance]',
#  '[temperature]',
#  '[]',
#  '[area]',
#  '[volume]',
#  '[frequency]',
#  '[wavenumber]',
#  '[velocity]',
#  '[speed]',
#  '[volumetric_flow_rate]',
#  '[acceleration]',
#  '[force]',
#  '[energy]',
#  '[power]',
#  '[momentum]',
#  '[density]',
#  '[pressure]',
#  '[torque]',
#  '[viscosity]',
#  '[kinematic_viscosity]',
#  '[fluidity]',
#  '[concentration]',
#  '[activity]',
#  '[entropy]',
#  '[molar_entropy]',
#  '[heat_transmission]',
#  '[luminance]',
#  '[luminous_flux]',
#  '[illuminance]',
#  '[intensity]',
#  '[charge]',
#  '[electric_potential]',
#  '[electric_field]',
#  '[electric_displacement_field]',
#  '[reduced_electric_field]',
#  '[resistance]',
#  '[resistivity]',
#  '[conductance]',
#  '[conductivity]',
#  '[capacitance]',
#  '[magnetic_flux]',
#  '[inductance]',
#  '[magnetic_field]',
#  '[magnetomotive_force]',
#  '[magnetic_field_strength]',
# ...

# %%
ureg.sys.__dir__()
# Out:
# ['SI', 'mks', 'cgs', 'atomic', 'Planck', 'imperial', 'US']

# %%
ureg.get_dimensionality("[temperature]")
# Out:
# <UnitsContainer({'[temperature]': 1})>

# %%
def get_unit_label(quantity, fmt="~HTML"):
    """Returns only the formatted unit string."""
    return f"{quantity.units:{fmt}}"

# Example usage for a pressure drop calculation
dp = 500 meter / second ** 2
header = f"Pressure Drop ({get_unit_label(dp)})"
print(header) # Output: Pressure Drop (Pa)
# Out:
#   Cell In[30], line 6
#     dp = 500 meter / second ** 2
#              ^
# SyntaxError: invalid syntax
